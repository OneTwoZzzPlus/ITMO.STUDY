# %% [markdown]
# # Тестирование

# %%
from meas import *

# %%
m = Measurement(0.40, 0.005)
n = Measurement(0.18, 0.005)
print(m)

print(m > n)

l = m + n
print(l)

print(l.format_latex())

mmm = DirectMultipleMeasurement([0.40, 0.50, 0.45, 0.47], 0.005)
print(mmm.rounded)
print(mmm.info())
# Out:
# 0.400±0.005 ε = 1.2
# True
# 0.580±0.010 ε = 1.7
# 0.580\pm0.010
# 0.46±0.07 ε = 15.0
#
# N = 4
# values = [0.4, 0.5, 0.45, 0.47]
# average = 0.46
# average_ = 0.455
# sigma_ = 0.021015867021530812
# delta = 0.07
# delta_ = 0.06691353458838584
# delta_instrumental = 0.005
# delta_random_ = 0.06683045712846798
# student = 3.18
# epsilon = 15.0
# epsilon_ = 14.706271338106777

# %%
data = LinearMultipleMeasurement(
    [Measurement(0.90, 0.20), Measurement(0.80, 0.15), Measurement(0.70, 0.10), Measurement(0.60, 0.05)],
    [Measurement(1.30, 0.20), Measurement(1.40, 0.15), Measurement(0.50, 0.10), Measurement(1.60, 0.05)]
)
print(data.info())
# Out:
# [0.90±0.20 ε = 22.0, 0.80±0.15 ε = 19.0, 0.70±0.10 ε = 14.0, 0.60±0.05 ε = 8.0]
# [1.30±0.20 ε = 15.0, 1.40±0.15 ε = 11.0, 0.50±0.10 ε = 20.0, 1.60±0.05 ε = 3.1]
# N = 4
# average = 0.76
# average_ = 0.7596840659340659
# delta = 0.22
# delta_ = 0.2232274686160665
# student = 1
# epsilon = 29.0
# epsilon_ = 29.38425045701047

# %%
data = DrawableMultipleMeasurement(
    [Measurement(0.90, 0.03), Measurement(0.80, 0.05), Measurement(0.70, 0.01), Measurement(0.60, 0.05)],
    [Measurement(2.00, 0.03), Measurement(1.90, 0.05), Measurement(1.70, 0.01), Measurement(1.60, 0.05)]
)
print(data.info())
data.plot_MKN()
# Out:
# [0.900±0.030 ε = 3.3, 0.80±0.05 ε = 6.0, 0.700±0.010 ε = 1.4, 0.60±0.05 ε = 8.0]
# [2.000±0.030 ε = 1.5, 1.90±0.05 ε = 2.6, 1.700±0.010 ε = 0.6, 1.60±0.05 ε = 3.1]
# N = 4
# average = 0.414
# average_ = 0.4144543343653251
# delta = 0.015
# delta_ = 0.015467467130288595
# student = 1
# epsilon = 3.7
# epsilon_ = 3.7320075694164743
# 1.3999999999999804 0.7500000000000067
# Время выполнения = 0:00:00.031352

# %%
data = LinearMultipleMeasurement(
    [Measurement(0.90, 0.20), Measurement(0.80, 0.15), Measurement(0.70, 0.10), Measurement(0.60, 0.05)],
    [Measurement(1.30, 0.20), Measurement(1.40, 0.15), Measurement(0.50, 0.10), Measurement(1.60, 0.05)]
)
print(data.info())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = LinearMultipleMeasurement(
#       2     [Measurement(0.90, 0.20), Measurement(0.80, 0.15), Measurement(0.70, 0.10), Measurement(0.60, 0.05), Measurement(0.40, 0.05)],
#       3     [Measurement(1.30, 0.20), Measurement(1.40, 0.15), Measurement(0.50, 0.10), Measurement(1.60, 0.05)]
#       4 )
#       5 print(data.info())
#
# File d:\ITMO.STUDY\PROGRAM\check-v2\meas\tools.py:61, in check_len.<locals>.wrapper(self, m1, m2, *args)
#      59 def wrapper(self, m1, m2, *args):
#      60     if len(m1) != len(m2):
# ---> 61         raise ValueError('Разные размеры массивов!')
#      62     return method_to_decorate(self, m1, m2, *args)
#
# ValueError: Разные размеры массивов!
